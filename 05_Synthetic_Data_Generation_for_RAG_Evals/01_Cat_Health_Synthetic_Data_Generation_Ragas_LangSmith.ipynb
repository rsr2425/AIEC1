# %% [markdown]
# # Synthetic Data Generation for RAG Evaluation
#
# Session 1 built a vector RAG application over a cat health guideline PDF. This
# session creates an evaluation dataset for that application and uses the dataset
# to compare two retrieval configurations. All generation, embedding, RAG, and
# judge requests are routed through Vercel AI Gateway.
#
# The workflow is:
#
# ~~~text
# corpus -> knowledge graph -> synthetic examples -> human review
#        -> LangSmith dataset -> baseline and candidate experiments
# ~~~
#
# Synthetic examples reduce the cost of getting started, but generated references
# are not automatically ground truth. We will inspect and curate them before using
# them as evaluation targets.
#
# > This is an educational cat health exercise, not veterinary advice. Generated
# > questions and answers must not be used to diagnose, prescribe, or replace a
# > veterinarian.
#
# ## Learning Outcomes
#
# By the end of this notebook, you will be able to:
#
# - Explain how Ragas builds a knowledge graph for test data generation.
# - Distinguish single-hop specific, multi-hop specific, and multi-hop abstract queries.
# - Generate and review synthetic questions, reference contexts, and reference answers.
# - Route generation, embeddings, RAG, and judge calls through Vercel AI Gateway.
# - Upload reviewed examples to a LangSmith dataset.
# - Evaluate answer correctness, answer groundedness, and retrieval relevance.
# - Run a controlled RAG experiment that changes one variable at a time.

# %% [markdown]
# ## Table of Contents
#
# - **Breakout Room #1: Synthetic Test Data with Ragas**
#   - Task 1: Environment Setup
#   - Task 2: Load the Cat Health Corpus
#   - Task 3: Build and Enrich a Knowledge Graph
#   - Task 4: Inspect the Query Distribution
#   - Task 5: Generate and Inspect a Synthetic Test Set
#   - Activity #1: Review and Curate the Dataset
# - **Breakout Room #2: RAG Evaluation with LangSmith**
#   - Task 6: Create a LangSmith Dataset
#   - Task 7: Build a Baseline RAG Application
#   - Task 8: Define RAG Evaluators
#   - Task 9: Run the Baseline Experiment
#   - Task 10: Change One Retrieval Variable and Re-Evaluate
#   - Activity #2: Compare, Diagnose, and Iterate
#   - Advanced Build: Add Robustness and Adversarial Cases

# %% [markdown]
# ---
# # Breakout Room #1
# ## Synthetic Test Data with Ragas
#
# Ragas uses the source corpus to create a richer representation of its topics and
# relationships. Query synthesizers then select scenarios from that representation
# and generate questions plus reference answers.
#
# The knowledge graph is a generation aid. It is not the graph used by the RAG
# application in Breakout Room #2.

# %% [markdown]
# ## Task 1: Environment Setup
#
# From the <code>05_Synthetic_Data_Generation_for_RAG_Evals</code> folder:
#
# ~~~bash
# uv sync
# ~~~
#
# Then select the environment created by uv as this notebook's kernel.
#
# Required accounts:
#
# - Vercel AI Gateway for generation, embeddings, the RAG answer model, and judges
# - LangSmith for the dataset and experiments
#
# A direct OpenAI API key is not required. The OpenAI SDK is used only as a
# protocol-compatible client pointed at Vercel AI Gateway.
#
# The default synthetic test set is intentionally small. Ragas generation and
# LLM-as-judge evaluation both make multiple model calls, so start small and scale
# only after inspecting quality.

# %% [markdown]
# ### Imports

# %%
#os.environ.setdefault("RAGAS_DO_NOT_TRACK", "true")

# %%
from __future__ import annotations

import os
from collections import Counter
from getpass import getpass
from importlib.metadata import version
from pathlib import Path
from uuid import uuid4

import instructor
from IPython.display import display
from openai import OpenAI
from pydantic import BaseModel, field_validator

from langchain_community.document_loaders import PyPDFLoader
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_qdrant import QdrantVectorStore
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langsmith import Client, evaluate
from openevals.llm import create_llm_as_judge
from openevals.prompts import (
    CORRECTNESS_PROMPT,
    RAG_GROUNDEDNESS_PROMPT,
    RAG_RETRIEVAL_RELEVANCE_PROMPT,
)

from ragas.embeddings import embedding_factory
from ragas.llms import llm_factory
from ragas.run_config import RunConfig
from ragas.testset import TestsetGenerator
from ragas.testset.graph import KnowledgeGraph, Node, NodeType
from ragas.testset.synthesizers import (
    MultiHopAbstractQuerySynthesizer,
    MultiHopSpecificQuerySynthesizer,
    SingleHopSpecificQuerySynthesizer,
    default_query_distribution,
)
from ragas.testset.transforms import (
    CustomNodeFilter,
    SummaryExtractor,
    apply_transforms,
    default_transforms_for_prechunked,
)

# %% [markdown]
# ### API Keys, Models, and Cost Controls
#
# The notebook reads model names and budgets from environment variables so you can
# tune cost without editing every cell. Vercel AI Gateway exposes an
# OpenAI-compatible endpoint, so the OpenAI and LangChain clients only need a
# different API key, base URL, and provider-qualified model ID.
#
# See the [Vercel AI Gateway Python documentation](https://vercel.com/docs/ai-gateway/sdks-and-apis/python)
# for the current authentication and endpoint details.
#
# LangSmith uses <code>LANGSMITH_TRACING</code>. The older
# <code>LANGCHAIN_TRACING_V2</code> name from the source notebook is no longer
# needed here.

# %%
gateway_api_key = (
    os.environ.get("AI_GATEWAY_API_KEY")
    or os.environ.get("VERCEL_OIDC_TOKEN")
)

if not gateway_api_key:
    gateway_api_key = getpass("Vercel AI Gateway API Key: ")
    os.environ["AI_GATEWAY_API_KEY"] = gateway_api_key

if not os.environ.get("LANGSMITH_API_KEY"):
    os.environ["LANGSMITH_API_KEY"] = getpass("LangSmith API Key: ")

os.environ.setdefault("LANGSMITH_TRACING", "true")
os.environ.setdefault(
    "LANGSMITH_PROJECT",
    "aim-session-5-synthetic-rag-evals",
)

GATEWAY_BASE_URL = os.environ.get(
    "AI_GATEWAY_BASE_URL",
    "https://ai-gateway.vercel.sh/v1",
)
GENERATOR_MODEL_NAME = os.environ.get(
    "AIM_GENERATOR_MODEL",
    "openai/gpt-5.4-mini",
)
RAG_MODEL_NAME = os.environ.get(
    "AIM_RAG_MODEL",
    "openai/gpt-5.4-mini",
)
JUDGE_MODEL_NAME = os.environ.get(
    "AIM_JUDGE_MODEL",
    "openai/gpt-5.4-mini",
)
EMBEDDING_MODEL_NAME = os.environ.get(
    "AIM_EMBEDDING_MODEL",
    "openai/text-embedding-3-small",
)
TESTSET_SIZE = int(os.environ.get("AIM_TESTSET_SIZE", "6"))
MAX_CONCURRENCY = int(os.environ.get("AIM_MAX_CONCURRENCY", "2"))

gateway_models = {
    "generator": GENERATOR_MODEL_NAME,
    "rag": RAG_MODEL_NAME,
    "judge": JUDGE_MODEL_NAME,
    "embedding": EMBEDDING_MODEL_NAME,
}
for role, model_name in gateway_models.items():
    if "/" not in model_name:
        raise ValueError(
            f"{role} model must use a provider-qualified AI Gateway ID: "
            f"{model_name!r}"
        )

print(f"Ragas: {version('ragas')}")
print(f"LangSmith: {version('langsmith')}")
print(f"AI Gateway: {GATEWAY_BASE_URL}")
print(f"Generator model: {GENERATOR_MODEL_NAME}")
print(f"RAG model: {RAG_MODEL_NAME}")
print(f"Judge model: {JUDGE_MODEL_NAME}")
print(f"Embedding model: {EMBEDDING_MODEL_NAME}")
print(f"Synthetic examples: {TESTSET_SIZE}")
print(f"LangSmith tracing: {os.environ['LANGSMITH_TRACING']}")
# Out:
# Ragas: 0.4.4.dev8+g298b68274
# LangSmith: 0.8.16
# AI Gateway: https://ai-gateway.vercel.sh/v1
# Generator model: openai/gpt-5.4-mini
# RAG model: openai/gpt-5.4-mini
# Judge model: openai/gpt-5.4-mini
# Embedding model: openai/text-embedding-3-small
# Synthetic examples: 6
# LangSmith tracing: false

# %% [markdown]
# ## Task 2: Load the Cat Health Corpus
#
# The corpus is the bundled 2021 AAHA/AAFP Feline Life Stage Guidelines PDF used
# in Session 1. <code>PyPDFLoader</code> extracts one LangChain document per page,
# including page metadata that survives later chunking.
#
# This gives the generator multiple related units to connect:
#
# - hydration and urinary signs
# - preventive care and senior care
# - dental pain and behavior changes
# - monitoring and emergency escalation

# %%
corpus_path = Path("data/cat_health_guidelines.pdf")

if not corpus_path.exists():
    raise FileNotFoundError(
        f"Expected the course corpus at {corpus_path.resolve()}"
    )

pdf_loader = PyPDFLoader(str(corpus_path))
source_documents = pdf_loader.load()
source_documents = [
    document
    for document in source_documents
    if len(document.page_content.strip()) >= 200
]

for index, document in enumerate(source_documents):
    page_number = int(document.metadata.get("page", index)) + 1
    document.metadata.update(
        {
            "source": corpus_path.name,
            "document_type": "feline_life_stage_guidelines",
            "page_number": page_number,
        }
    )

print(f"Loaded {len(source_documents)} text-containing PDF pages")
for document in source_documents[:5]:
    page_number = document.metadata["page_number"]
    print(
        f"- page {page_number}: "
        f"{len(document.page_content)} characters"
    )
# Out:
# Loaded 20 text-containing PDF pages
# - page 1: 4913 characters
# - page 2: 2084 characters
# - page 3: 5955 characters
# - page 6: 5673 characters
# - page 7: 3588 characters

# %% [markdown]
# Inspect one PDF page and its metadata. The metadata is useful for debugging,
# trace inspection, and explaining where a retrieved chunk came from.

# %%
sample_document = source_documents[0]

print(sample_document.metadata)
print()
print(sample_document.page_content[:800])
# Out:
# {'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 0, 'page_label': '1', 'document_type': 'feline_life_stage_guidelines', 'page_number': 1}
#
# VETERINARY PRACTICE GUIDELINES
# 2021 AAHA/AAFP Feline Life Stage Guidelines*
# Jessica Quimby, DVM, PhD, DACVIM y, Shannon Gowland, DVM, DABVP y, Hazel C. Carney, DVM, MS, DABVP,
# Theresa DePorter, DVM, MRCVS, DACVB, DECAWBM, Paula Plummer, LVT, VTS (ECC, SAIM), Jodi Westropp,
# DVM, PhD, DACVIM
# ABSTRACT
# The guidelines, authored by a Task Force ofexperts in feline clinical medicine, are an update and extension of the AAFP–AAHA
# Feline Life Stage Guidelines published in 2010. The guidelines are published simultaneously in theJournal of Feline Medicine and
# Surgery(volume 23, issue 3, pages 211–233, DOI: 10.1177/1098612X21993657) and theJournal of the American Animal Hospital
# Association(volume 57, issue 2, pages 51–72, DOI: 10.5326/JAAHA-MS-7189). A noteworthy change from the earlier guidelines is

# %% [markdown]
# ## Task 3: Build and Enrich a Knowledge Graph
#
# The unrolled workflow makes the generation stages visible:
#
# 1. Treat each text-containing PDF page as a pre-chunked Ragas node.
# 2. Run Ragas extractors, embeddings, and relationship builders.
# 3. Save the graph so expensive enrichment can be reused.
#
# Ragas remains responsible for graph enrichment and synthetic generation. The
# newer pinned Ragas build exposes an official Instructor mode parameter, so its
# LLM factory can use AI Gateway tool calls directly without custom wrappers.

# %%
gateway_client = OpenAI(
    api_key=gateway_api_key,
    base_url=GATEWAY_BASE_URL,
)

generator_llm = llm_factory(
    GENERATOR_MODEL_NAME,
    provider="openai",
    client=gateway_client,
    mode=instructor.Mode.TOOLS,
    max_tokens=4096,
)
# Provider-qualified Gateway IDs bypass Ragas's GPT-5 parameter detection.
# Keep only the token limit supported by the Gateway route. max_retries is
# consumed locally by Instructor and is not sent to AI Gateway.
generator_llm.model_args = {
    "max_tokens": 4096,
    "max_retries": 3,
}

generator_embeddings = embedding_factory(
    "openai",
    model=EMBEDDING_MODEL_NAME,
    client=gateway_client,
)

ragas_run_config = RunConfig(
    timeout=180,
    max_retries=3,
    max_wait=30,
    max_workers=MAX_CONCURRENCY,
)
# Out:
# /var/folders/6c/7q3zr6zs7lvfblgs0bncb4bh0000gn/T/ipykernel_7670/1199448542.py:21: DeprecationWarning: Importing embedding_factory from ragas.embeddings is deprecated. Import directly from ragas.embeddings.base or use modern providers: from ragas.embeddings import OpenAIEmbeddings, GoogleEmbeddings, HuggingFaceEmbeddings
#   generator_embeddings = embedding_factory(

# %% [markdown]
# Before building the graph, make one small structured-output request through
# Ragas. This catches gateway authentication, model availability, and tool-calling
# incompatibilities without waiting for every PDF page to retry.

# %%
class GatewayToolCallCheck(BaseModel):
    status: str


class NonEmptySummary(BaseModel):
    text: str

    @field_validator("text")
    @classmethod
    def require_text(cls, value):
        value = value.strip()
        if not value:
            raise ValueError("summary text cannot be empty")
        return value


gateway_check = generator_llm.generate(
    "Use the required tool with a short, non-empty status message.",
    GatewayToolCallCheck,
)
if not gateway_check.status.strip():
    raise RuntimeError("AI Gateway returned an empty tool-call check")

print(f"AI Gateway tool-based structured output: {gateway_check.status}")
# Out:
# AI Gateway tool-based structured output: ok

# %%
def build_prechunked_knowledge_graph(chunks):
    return KnowledgeGraph(
        nodes=[
            Node(
                type=NodeType.CHUNK,
                properties={
                    "page_content": chunk.page_content,
                    "document_metadata": dict(chunk.metadata),
                },
            )
            for chunk in chunks
            if chunk.page_content.strip()
        ]
    )


generation_chunks = list(source_documents)
knowledge_graph = build_prechunked_knowledge_graph(generation_chunks)

print(f"Ragas input chunks: {len(generation_chunks)}")
print(knowledge_graph)
# Out:
# Ragas input chunks: 20
# KnowledgeGraph(nodes: 20, relationships: 0)

# %% [markdown]
# ### Apply Ragas Transforms
#
# Because the PDF loader already gives us coherent page-level chunks, use Ragas'
# built-in pre-chunked transform pipeline. It skips headline extraction and
# splitting, then applies Ragas summaries, embeddings, themes, named entities,
# and relationship builders directly to the PDF pages. The parent-child node
# filter is omitted because these page chunks intentionally have no parent nodes.
# A non-empty output constraint makes Instructor retry blank Ragas summaries before
# the built-in embedding transform runs.

# %%
# workaround to disable LangSmith tracing for Ragas generation, since it is not needed and ran into lots of rate-limiting errors
os.environ["LANGSMITH_TRACING"] = "false"
print("LangSmith tracing disabled for Ragas generation")
# Out:
# LangSmith tracing disabled for Ragas generation

# %%
knowledge_graph = build_prechunked_knowledge_graph(generation_chunks)
transforms = [
    transform
    for transform in default_transforms_for_prechunked(
        llm=generator_llm,
        embedding_model=generator_embeddings,
    )
    if not isinstance(transform, CustomNodeFilter)
]

summary_transform = next(
    transform
    for transform in transforms
    if isinstance(transform, SummaryExtractor)
)
summary_transform.prompt.output_model = NonEmptySummary

print("Ragas transform pipeline:")
for transform in transforms:
    nested = getattr(transform, "transformations", None)
    if nested is None:
        print(f"- {type(transform).__name__}")
    else:
        names = ", ".join(type(item).__name__ for item in nested)
        print(f"- Parallel({names})")

for transform in transforms:
    apply_transforms(
        knowledge_graph,
        transform,
        run_config=ragas_run_config,
    )
    if isinstance(transform, SummaryExtractor):
        empty_summary_nodes = [
            node
            for node in knowledge_graph.nodes
            if not str(node.get_property("summary") or "").strip()
        ]
        if empty_summary_nodes:
            raise RuntimeError(
                "Ragas did not produce non-empty summaries for "
                f"{len(empty_summary_nodes)} PDF chunks"
            )

print(knowledge_graph)
# Out:
# Ragas transform pipeline:
# - SummaryExtractor
# - Parallel(EmbeddingExtractor, ThemesExtractor, NERExtractor)
# - Parallel(CosineSimilarityBuilder, OverlapScoreBuilder)
# Applying SummaryExtractor: 100%|██████████| 20/20 [00:47<00:00,  2.39s/it]
# Applying [EmbeddingExtractor, ThemesExtractor, NERExtractor]:   0%|          | 0/60 [00:00<?, ?it/s]/Users/ryanrodriguez/src/AIEC1/05_Synthetic_Data_Generation_for_RAG_Evals/.venv/lib/python3.13/site-packages/ragas/testset/transforms/base.py:198: UserWarning: Using sync embedding model OpenAIEmbeddings in async context. This may impact performance. Consider using an async-compatible embedding model for better performance.
#   property_name, property_value = await self.extract(node)
# Applying [EmbeddingExtractor, ThemesExtractor, NERExtractor]: 100%|██████████| 60/60 [00:57<00:00,  1.05it/s]
# Applying [CosineSimilarityBuilder, OverlapScoreBuilder]: 100%|██████████| 2/2 [00:00<00:00, 204.43it/s]
# KnowledgeGraph(nodes: 20, relationships: 55)

# %% [markdown]
# Inspect the graph at a high level. Different Ragas versions may add different
# properties, so the notebook avoids depending on one exact internal schema.

# %%
node_type_counts = Counter(str(node.type) for node in knowledge_graph.nodes)

print("Node types:")
for node_type, count in node_type_counts.items():
    print(f"- {node_type}: {count}")

print(f"Relationships: {len(knowledge_graph.relationships)}")

for index, node in enumerate(knowledge_graph.nodes[:3], start=1):
    property_names = sorted(node.properties.keys())
    print(f"Node {index} properties: {property_names}")
# Out:
# Node types:
# - NodeType.CHUNK: 20
# Relationships: 55
# Node 1 properties: ['document_metadata', 'entities', 'page_content', 'summary', 'summary_embedding', 'themes']
# Node 2 properties: ['document_metadata', 'entities', 'page_content', 'summary', 'summary_embedding', 'themes']
# Node 3 properties: ['document_metadata', 'entities', 'page_content', 'summary', 'summary_embedding', 'themes']

# %%
print(f"Node 1: {knowledge_graph.nodes[0]}")
# Out:
# Node 1: Node(id: b35664, type: NodeType.CHUNK, properties: ['page_content', 'document_metadata', 'summary', 'summary_embedding', 'themes', 'entities'])

# %%
print(f"Node 1 summary: {knowledge_graph.nodes[0].get_property('summary')}")
# Out:
# Node 1 summary: The 2021 AAHA/AAFP feline guidelines update earlier recommendations by organizing cats into five life stages, including an end-of-life stage, to support individualized lifelong care. They provide a structured wellness-visit framework and cover key areas such as behavior, elimination, nutrition, weight management, oral health, parasite control, vaccination, zoonoses, and stage-based diagnostics. The document also offers practical advice for overcoming barriers to regular veterinary visits.

# %%
for property_name, property_value in knowledge_graph.nodes[0].properties.items():
    print(f"Node 1 property '{property_name}': {property_value}")
# Out:
# Node 1 property 'page_content': VETERINARY PRACTICE GUIDELINES
# 2021 AAHA/AAFP Feline Life Stage Guidelines*
# Jessica Quimby, DVM, PhD, DACVIM y, Shannon Gowland, DVM, DABVP y, Hazel C. Carney, DVM, MS, DABVP,
# Theresa DePorter, DVM, MRCVS, DACVB, DECAWBM, Paula Plummer, LVT, VTS (ECC, SAIM), Jodi Westropp,
# DVM, PhD, DACVIM
# ABSTRACT
# The guidelines, authored by a Task Force ofexperts in feline clinical medicine, are an update and extension of the AAFP–AAHA
# Feline Life Stage Guidelines published in 2010. The guidelines are published simultaneously in theJournal of Feline Medicine and
# Surgery(volume 23, issue 3, pages 211–233, DOI: 10.1177/1098612X21993657) and theJournal of the American Animal Hospital
# Association(volume 57, issue 2, pages 51–72, DOI: 10.5326/JAAHA-MS-7189). A noteworthy change from the earlier guidelines is
# the division of the cat’sl i f e s p a ni n t oaﬁve-stage grouping with four distinct age-related stages (kitten, young adult, mature adult,
# and senior) as well as an end-of-life stage, instead of the previous six. This simpliﬁed grouping is consistent with how pet owners
# generally perceive their cat’s maturation and aging process, and provides a readily understood basis for an evolving, individualized,
# lifelong feline healthcare strategy. The guidelines include a comprehensive table on the components of a feline wellness visit that
# provides a framework for systematically implementing an individualized life stage approach to fe line healthcare. Included are
# recommendations for managing the most critical health-related factors in relation to a cat’s life stage. These recommendations are
# further explained in the followi ng categories: behavior and envir onmental needs; elimination; life stage nutrition and weight
# management; oral health; parasite control; vaccination; zoonoses and human safety; and recommended diagnostics based on
# life stage. A discussion on overcoming barriers to veterinary v i s i t sb yc a to w n e r so f f e r sp r a ctical advice on one of the most
# challenging aspects of delivering regular feline healthcare.(JA mA n i mH o s pA s s o c2021; 57:51–72. DOI 10.5326/JAAHA-MS-7189)
# AFFILIATIONS
# The Ohio State University, Department of V eterinary Clinical Sciences, Co-
# lumbus, Ohio, USA (J.Q.); OVC Smith Lane Animal Hospital, Ontario V et-
# erinary College, Guelph, Ontario, Canada (S.G.); WestV et Emergency and
# Specialty Center, Garden City, Idaho, USA (H.C.C.); Oakland V eterinary
# Referral Services, Bloom ﬁeld Hills, Michigan, USA (T.D.); T exas A&M Uni-
# versity V eterinary Medical T eaching Hospital, College Station, T exas, USA
# (P .P .); and University of California, Davis, School of V eterinary Medicine,
# Davis, California, USA (J.W.).
# KEYWORDS
# Feline life stage; kitten; adult; senior; veterinary; healthcare examination;
# medical history; behavior; risk assessment; elimination
# Correspondence: quimby.19@osu.edu (J.Q.)
# * Boehringer Ingelheim Animal Health USA Inc., CareCredit, Dechra Vet-
# erinary Products, IDEXX Laboratories, Inc., Merck Animal Health, and Zoetis
# Petcare supported the development of the 2021 AAHA/AAFP Feline Life
# Stage Guidelinesand resources through an educational grant to AAHA.
# † J. Quimby and S. Gowland were cochairs of the 2021 AAHA/AAFP
# Feline Life Stage Guidelines Task Force.
# These guidelines were prepared by a Task Force of experts convened
# by the American Animal Hospital Association (AAHA) and the American
# Association of Feline Practitioners (AAFP) and were subjected to a for-
# mal peer-review process. This document is intended as a guideline only,
# not an AAHA or AAFP standard of care. These guidelines and recom-
# mendations should not be construed as dictating an exclusive protocol,
# course of treatment, or procedure. Variations in practice may be war-
# ranted based on the needs of the individual patient, resources, and
# limitations unique to each individual practice setting. Evidence-based
# support for speciﬁc recommendations has been cited whenever pos-
# sible and appropriate.
# Other recommendations are based on practical clinical experience and
# a consensus of expert opinion. Further research is needed to document
# some of these recommendations. Because each case is different, vet-
# erinarians must base their decisions on the best available scientiﬁc ev-
# idence in conjunction with their own knowledge and experience.
# BCS (body condition score); DER (daily energy requirements); DJD
# (degenerative joint disease); FCV (feline calicivirus); FeLV (feline leukemia
# virus); FHV-1 (feline herpesvirus type 1); FIC (feline idiopathic cystitis);
# FPV (feline panleukopenia virus); GI (gastrointestinal); HARD (heartworm-
# associated respiratory disease); MCS (muscle condition score); RER
# (resting energy requirements); T4 (thyroxine)
# Accepted for publication: October 4, 2020.
# ª 2021 by American Animal Hospital Association, American Association of Feline Practitioners, and International Society of Feline Medicine JAAHA.ORG 51
# Node 1 property 'document_metadata': {'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 0, 'page_label': '1', 'document_type': 'feline_life_stage_guidelines', 'page_number': 1}
# Node 1 property 'summary': The 2021 AAHA/AAFP feline guidelines update earlier recommendations by organizing cats into five life stages, including an end-of-life stage, to support individualized lifelong care. They provide a structured wellness-visit framework and cover key areas such as behavior, elimination, nutrition, weight management, oral health, parasite control, vaccination, zoonoses, and stage-based diagnostics. The document also offers practical advice for overcoming barriers to regular veterinary visits.
# Node 1 property 'summary_embedding': [0.047760009765625, -0.026763916015625, 0.08624267578125, 0.03778076171875, -0.0240478515625, 0.0257568359375, -0.0438232421875, -0.01654052734375, 0.0199737548828125, 0.061065673828125, 0.045440673828125, -0.0416259765625, -0.0235595703125, 0.01003265380859375, -0.0155181884765625, 0.0229949951171875, 0.031524658203125, 0.0252227783203125, 0.01142120361328125, 0.01012420654296875, 0.039398193359375, -0.0193328857421875, -0.0020236968994140625, -0.02398681640625, -0.03802490234375, -0.01186370849609375, -0.013275146484375, 0.0321044921875, 0.01605224609375, -0.0279541015625, 0.02398681640625, -0.0328369140625, -0.00029921531677246094, -0.01479339599609375, -0.0738525390625, 0.022125244140625, 0.00743865966796875, -0.02294921875, 0.0244140625, -0.0086669921875, -0.0029544830322265625, 0.00868988037109375, 0.032501220703125, 0.014190673828125, 0.0136260986328125, 0.0114288330078125, 0.053466796875, -0.031829833984375, 0.006916046142578125, -0.01398468017578125, -0.01097869873046875, -0.0155792236328125, 0.01438140869140625, 0.01910400390625, -0.002506256103515625, -0.0033092498779296875, 0.033355712890625, -0.0195465087890625, 0.0102996826171875, 0.040374755859375, 0.03338623046875, 0.00045990943908691406, 0.0457763671875, -0.017578125, -0.033935546875, -0.015625, -0.01275634765625, 0.01364898681640625, 0.0008325576782226562, -0.02880859375, 0.0162200927734375, 0.0102691650390625, 6.347894668579102e-05, 0.00711822509765625, 0.0209808349609375, 0.00884246826171875, -0.0408935546875, 0.036712646484375, 0.01108551025390625, 0.0340576171875, -0.004726409912109375, 0.034820556640625, -0.00689697265625, 0.01800537109375, 0.0271453857421875, 0.01123809814453125, -0.00836181640625, -0.0411376953125, -0.034637451171875, -0.00612640380859375, 0.02581787109375, 0.038818359375, -0.0626220703125, 0.00989532470703125, 0.021331787109375, 0.0097198486328125, 0.01177215576171875, -0.03814697265625, -0.007801055908203125, -0.00212860107421875, -0.006710052490234375, -0.036102294921875, -0.0516357421875, 0.01666259765625, 0.019866943359375, -0.042205810546875, 0.00614166259765625, 0.01364898681640625, -0.005077362060546875, -0.00160980224609375, -0.06060791015625, -0.026275634765625, -0.0078277587890625, 0.0562744140625, -0.050018310546875, -0.0176239013671875, -0.048919677734375, 0.01546478271484375, 0.0010128021240234375, -0.002689361572265625, 0.02392578125, 0.0439453125, 0.0031986236572265625, -0.04901123046875, 0.005161285400390625, 0.02783203125, -0.005523681640625, 0.01708984375, -0.06072998046875, -0.0760498046875, -0.0116729736328125, -0.0089874267578125, 0.0245819091796875, -0.047271728515625, -0.07720947265625, -0.016815185546875, -0.0267333984375, -0.0303802490234375, -0.033050537109375, 0.00986480712890625, 0.059906005859375, -0.038482666015625, -0.01302337646484375, 0.006565093994140625, -0.0099639892578125, -0.00872802734375, 0.0141448974609375, 0.04266357421875, -0.027130126953125, -0.00763702392578125, -0.0240020751953125, 0.0555419921875, 0.00440216064453125, -0.0050201416015625, 0.0007510185241699219, 0.02447509765625, -0.0132293701171875, -0.031768798828125, -0.001392364501953125, -0.025970458984375, -0.0300445556640625, -0.0200042724609375, 0.0328369140625, 0.049224853515625, 0.029052734375, -0.014862060546875, -0.021820068359375, 0.00795745849609375, -0.039764404296875, 0.0265655517578125, -0.0218048095703125, -0.05078125, -0.010467529296875, -0.0261077880859375, -0.020477294921875, -0.0013818740844726562, -0.0009183883666992188, -0.006649017333984375, -0.0231170654296875, -0.012908935546875, 0.0117340087890625, 0.01995849609375, -0.041412353515625, -0.00079345703125, -0.058074951171875, 0.0296630859375, 0.00799560546875, 0.0271759033203125, -0.033203125, 0.0038089752197265625, -0.00026869773864746094, -0.01104736328125, 0.0209197998046875, 0.0273895263671875, 0.037872314453125, 0.0230560302734375, 0.01259613037109375, -0.042388916015625, 0.028839111328125, -0.01129913330078125, -0.0134582 ...
# Node 1 property 'themes': ['Feline life stage guidelines', 'Veterinary practice guidelines', 'Cat healthcare across life stages', 'Kitten care', 'Young adult cat care', 'Mature adult cat care', 'Senior cat care', 'End-of-life care', 'Individualized lifelong healthcare', 'Wellness examinations', 'Behavior and environmental needs', 'Elimination issues', 'Nutrition and weight management', 'Oral health', 'Parasite control', 'Vaccination', 'Zoonoses and human safety', 'Diagnostic recommendations', 'Medical history and risk assessment', 'Barriers to veterinary visits', 'Evidence-based veterinary recommendations']
# Node 1 property 'entities': ['American Animal Hospital Association', 'American Association of Feline Practitioners', 'International Society of Feline Medicine', 'Journal of Feline Medicine and Surgery', 'Journal of the American Animal Hospital Association', 'The Ohio State University', 'Texas A&M University', 'University of California, Davis', 'Boehringer Ingelheim Animal Health USA Inc.', 'IDEXX Laboratories, Inc.']

# %%
# print first three relationships
for index, relationship in enumerate(knowledge_graph.relationships, start=1):
    print(f"Relationship {index}: {relationship}")
# Out:
# Relationship 1: Relationship(Node(id: 7c7339) <-> Node(id: 2b3067), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 2: Relationship(Node(id: 97a339) <-> Node(id: 7c7339), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 3: Relationship(Node(id: b35664) <-> Node(id: 8f10d7), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 4: Relationship(Node(id: 7c7339) <-> Node(id: 011c8f), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 5: Relationship(Node(id: 75f679) <-> Node(id: 7c7339), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 6: Relationship(Node(id: 7c7339) <-> Node(id: c71ce7), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 7: Relationship(Node(id: 7c7339) <-> Node(id: 4b9505), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 8: Relationship(Node(id: 8c1579) <-> Node(id: 8f10d7), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 9: Relationship(Node(id: fe546e) <-> Node(id: 8f10d7), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 10: Relationship(Node(id: 011c8f) <-> Node(id: 8f10d7), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 11: Relationship(Node(id: 011c8f) <-> Node(id: eb45ee), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 12: Relationship(Node(id: 1fb569) <-> Node(id: eb45ee), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 13: Relationship(Node(id: fe546e) <-> Node(id: 97a339), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 14: Relationship(Node(id: 1fb569) <-> Node(id: b0bf4f), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 15: Relationship(Node(id: c5fd77) <-> Node(id: 8f10d7), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 16: Relationship(Node(id: 2b3067) <-> Node(id: 4b9505), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 17: Relationship(Node(id: 8f10d7) <-> Node(id: eb45ee), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 18: Relationship(Node(id: 8c1579) <-> Node(id: 75f679), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 19: Relationship(Node(id: fcca8a) <-> Node(id: c5fd77), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 20: Relationship(Node(id: fcca8a) <-> Node(id: 8f10d7), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 21: Relationship(Node(id: 97a339) <-> Node(id: eb45ee), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 22: Relationship(Node(id: 8c1579) <-> Node(id: c5fd77), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 23: Relationship(Node(id: b35664) <-> Node(id: 75f679), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 24: Relationship(Node(id: b35664) <-> Node(id: 97a339), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 25: Relationship(Node(id: 7c7339) <-> Node(id: 8f10d7), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 26: Relationship(Node(id: 75f679) <-> Node(id: 7044a4), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 27: Relationship(Node(id: 75f679) <-> Node(id: fcca8a), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 28: Relationship(Node(id: fe546e) <-> Node(id: 75f679), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 29: Relationship(Node(id: 8c1579) <-> Node(id: 7c7339), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 30: Relationship(Node(id: 4b9505) <-> Node(id: 8f10d7), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 31: Relationship(Node(id: eb45ee) <-> Node(id: b0bf4f), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 32: Relationship(Node(id: 7044a4) <-> Node(id: 7c7339), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 33: Relationship(Node(id: fe546e) <-> Node(id: 7c7339), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 34: Relationship(Node(id: 8c1579) <-> Node(id: fcca8a), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 35: Relationship(Node(id: 7c7339) <-> Node(id: 1fb569), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 36: Relationship(Node(id: c71ce7) <-> Node(id: 4b9505), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 37: Relationship(Node(id: b35664) <-> Node(id: eb45ee), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 38: Relationship(Node(id: 97a339) <-> Node(id: 8f10d7), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 39: Relationship(Node(id: 4b9505) <-> Node(id: 011c8f), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 40: Relationship(Node(id: 75f679) <-> Node(id: 8f10d7), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 41: Relationship(Node(id: b35664) <-> Node(id: fe546e), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 42: Relationship(Node(id: 75f679) <-> Node(id: 011c8f), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 43: Relationship(Node(id: fe546e) <-> Node(id: 8c1579), type: summary_similarity, properties: ['summary_similarity'])
# Relationship 44: Relationship(Node(id: b35664) <-> Node(id: 8f10d7), type: entities_overlap, properties: ['entities_overlap_score', 'overlapped_items'])
# Relationship 45: Relationship(Node(id: fe546e) <-> Node(id: fcca8a), type: entities_overlap, properties: ['entities_overlap_score', 'overlapped_items'])
# Relationship 46: Relationship(Node(id: 97a339) <-> Node(id: 76d8bf), type: entities_overlap, properties: ['entities_overlap_score', 'overlapped_items'])
# Relationship 47: Relationship(Node(id: 97a339) <-> Node(id: 2b3067), type: entities_overlap, properties: ['entities_overlap_score', 'overlapped_items'])
# Relationship 48: Relationship(Node(id: 97a339) <-> Node(id: c5fd77), type: entities_overlap, properties: ['entities_overlap_score', 'overlapped_items'])
# Relationship 49: Relationship(Node(id: 97a339) <-> Node(id: b0bf4f), type: entities_overlap, properties: ['entities_overlap_score', 'overlapped_items'])
# Relationship 50: Relationship(Node(id: 7c7339) <-> Node(id: 2b3067), type: entities_overlap, properties: ['entities_overlap_score', 'overlapped_items'])
# Relationship 51: Relationship(Node(id: 7c7339) <-> Node(id: 4b9505), type: entities_overlap, properties: ['entities_overlap_score', 'overlapped_items'])
# Relationship 52: Relationship(Node(id: 2b3067) <-> Node(id: 4b9505), type: entities_overlap, properties: ['entities_overlap_score', 'overlapped_items'])
# Relationship 53: Relationship(Node(id: 2b3067) <-> Node(id: c5fd77), type: entities_overlap, properties: ['entities_overlap_score', 'overlapped_items'])
# Relationship 54: Relationship(Node(id: 2b3067) <-> Node(id: b0bf4f), type: entities_overlap, properties: ['entities_overlap_score', 'overlapped_items'])
# Relationship 55: Relationship(Node(id: c5fd77) <-> Node(id: b0bf4f), type: entities_overlap, properties: ['entities_overlap_score', 'overlapped_items'])

# %% [markdown]
# ### Save and Reload the Graph
#
# Generated artifacts go in the ignored <code>artifacts/</code> folder so running
# the notebook does not add large, machine-generated files to the assignment diff.

# %%
artifacts_dir = Path("artifacts")
artifacts_dir.mkdir(exist_ok=True)

knowledge_graph_path = artifacts_dir / "cat_health_knowledge_graph.json"
knowledge_graph.save(str(knowledge_graph_path))

loaded_knowledge_graph = KnowledgeGraph.load(str(knowledge_graph_path))

print(f"Saved graph to {knowledge_graph_path}")
print(loaded_knowledge_graph)
# Out:
# Saved graph to artifacts/cat_health_knowledge_graph.json
# KnowledgeGraph(nodes: 20, relationships: 55)

# %% [markdown]
# #### ❓ Question #1
#
# What information did the Ragas graph transforms add beyond the original text,
# and why are the two relationship types important for multi-hop questions?
#
# ##### ✅ Answer
# `['document_metadata', 'entities', 'page_content', 'summary', 'summary_embedding', 'themes']`
#
# We initialized the graph solely with the properties
# - page_content
# - document_metadata
#
# But as you can see above, the list of properties now also includes which were generated by the RAGAS graph transforms.
# - summary
# - summary_embedding
# - entities
# - themes
#
# If we inspect the relationships, we see two distinct types
# 1. summary_similarity
# 2. entities_overlap
# These are important because they indicate nodes who have similiar content (i.e. their semantic meaning is either similar OR they're talking about the same entities).

# %% [markdown]
# ## Task 4: Inspect the Query Distribution
#
# Ragas can synthesize several kinds of questions:
#
# | Query type | What it tests |
# |---|---|
# | Single-hop specific | Retrieve one concrete fact or recommendation from one context |
# | Multi-hop specific | Combine concrete details from multiple related contexts |
# | Multi-hop abstract | Connect broader themes or concepts across contexts |
#
# The distribution is part of the evaluation specification. It determines which
# behaviors are common in the generated dataset.

# %%
query_distribution = default_query_distribution(
    generator_llm,
    kg=loaded_knowledge_graph,
)

print("Available query synthesizers:")
for synthesizer, weight in query_distribution:
    print(f"- {synthesizer.name}: {weight:.0%}")

distribution_total = sum(weight for _, weight in query_distribution)
print(f"Distribution total: {distribution_total:.2f}")
# Out:
# Available query synthesizers:
# - single_hop_specific_query_synthesizer: 33%
# - multi_hop_abstract_query_synthesizer: 33%
# - multi_hop_specific_query_synthesizer: 33%
# Distribution total: 1.00

# %% [markdown]
# ### Define a Custom Distribution
#
# The default is a sensible starting point, but the mix should reflect the
# application behavior you care about. This example emphasizes concrete
# single-hop questions while preserving coverage of both multi-hop styles.
#
# Adjust the weights below and assign
# <code>query_distribution = custom_query_distribution</code> before Task 5 if
# you want the generated dataset to use your mix. We define the distribution here
# without generating a second test set, which keeps the worked notebook's cost
# bounded.
#
# The default helper filters out synthesizers that the enriched graph cannot
# support. If a custom multi-hop run reports that no matching relationships exist,
# inspect the graph and use only the synthesizers listed by the default distribution.

# %%
custom_query_distribution = [
    (
        SingleHopSpecificQuerySynthesizer(llm=generator_llm),
        0.50,
    ),
    (
        MultiHopSpecificQuerySynthesizer(llm=generator_llm),
        0.30,
    ),
    (
        MultiHopAbstractQuerySynthesizer(llm=generator_llm),
        0.20,
    ),
]

assert abs(
    sum(weight for _, weight in custom_query_distribution) - 1.0
) < 1e-9

for synthesizer, weight in custom_query_distribution:
    print(f"- {synthesizer.name}: {weight:.0%}")
# Out:
# - single_hop_specific_query_synthesizer: 50%
# - multi_hop_specific_query_synthesizer: 30%
# - multi_hop_abstract_query_synthesizer: 20%

# %% [markdown]
# #### ❓ Question #2
#
# Describe the three query types in your own words. Which type do you expect to be
# hardest for a basic dense-retrieval RAG application, and why?
#
# ##### ✅ Answer
# The 3 types
# - Single hop specific query - A query about a specific fact that can be answered by retrieving one single chunk.
# - Multi hop specific query - A query about a specific fact which can only be answered by retrieving multiple chunks.
# - Multi hop abstract query - A query about more general concepts/abstract ideas fact which can only be answered by retrieving multiple chunks.
#
# Multi hop abstract queries should be the hardest. Not only do you have to retrieve all multiple relevant chunks to hope to get the right answer, you need to synthesize them in the right way which may not be clear or requires a judgement call.

# %% [markdown]
# ## Task 5: Generate and Inspect a Synthetic Test Set
#
# Each generated row contains:
#
# - <code>user_input</code>: the synthetic question
# - <code>reference_contexts</code>: source context selected by the generator
# - <code>reference</code>: a generated reference answer
# - <code>synthesizer_name</code>: the query strategy that produced the row
#
# The reference is generated from selected source context. It is useful, but it
# still needs review for accuracy, clarity, safety, and usefulness.

# %%
testset_generator = TestsetGenerator(
    llm=generator_llm,
    embedding_model=generator_embeddings,
    knowledge_graph=loaded_knowledge_graph,
)

synthetic_testset = testset_generator.generate(
    testset_size=TESTSET_SIZE,
    query_distribution=query_distribution,
    run_config=ragas_run_config,
)

testset_df = synthetic_testset.to_pandas()

display(
    testset_df[
        [
            "user_input",
            "reference",
            "synthesizer_name",
        ]
    ]
)
# Out:
# Generating personas: 100%|██████████| 3/3 [00:04<00:00,  1.36s/it]
# Generating Scenarios: 100%|██████████| 3/3 [00:19<00:00,  6.36s/it]
# Generating Samples: 100%|██████████| 6/6 [00:10<00:00,  1.75s/it]
#                                           user_input  \
# 0  What does the context say about Texas A&M Univ...
# 1  What is spxChrome/E+ in the context of this fe...
# 2  How do client education and compliance improve...
# 3  How do the guidelines connect nail trimming an...
# 4  According to the feline life stage guidelines ...
# 5  According to the ISFM-related feline life stag...
#
#                                            reference  \
# 0  The context lists Texas A&M University Veterin...
# 1  spxChrome/E+ is listed in the image credits at...
# 2  Client education is described as a key respons...
# 3  The guidelines say that keeping a cat’s nails ...
# 4  Each examination visit should include a life s...
# 5  The guidelines explain that a life-stage-based...
#
#                         synthesizer_name
# 0  single_hop_specific_query_synthesizer
# 1  single_hop_specific_query_synthesizer
# 2   multi_hop_abstract_query_synthesizer
# 3   multi_hop_abstract_query_synthesizer
# 4   multi_hop_specific_query_synthesizer
# 5   multi_hop_specific_query_synthesizer

# %%
testset_path = artifacts_dir / "cat_health_synthetic_testset.jsonl"
testset_df.to_json(
    testset_path,
    orient="records",
    lines=True,
    force_ascii=False,
)

print("Examples by synthesizer:")
print(testset_df["synthesizer_name"].value_counts())
print()
print(f"Saved candidate examples to {testset_path}")
# Out:
# Examples by synthesizer:
# synthesizer_name
# single_hop_specific_query_synthesizer    2
# multi_hop_abstract_query_synthesizer     2
# multi_hop_specific_query_synthesizer     2
# Name: count, dtype: int64
#
# Saved candidate examples to artifacts/cat_health_synthetic_testset.jsonl

# %% [markdown]
# ### Abstracted Ragas Alternative
#
# The graph-first path above makes each Ragas stage inspectable and lets you save
# the enriched graph before generation. Ragas also provides a one-call helper for
# content that is already chunked:
#
# ~~~python
# quick_generator = TestsetGenerator(
#     llm=generator_llm,
#     embedding_model=generator_embeddings,
# )
# quick_testset = quick_generator.generate_with_chunks(
#     chunks=generation_chunks,
#     testset_size=TESTSET_SIZE,
#     transforms=transforms,
#     run_config=ragas_run_config,
# )
# ~~~
#
# This alternative is shown rather than executed so the notebook does not repeat
# the same billable graph enrichment and test-set generation.

# %% [markdown]
# #### ❓ Question #3
#
# What are the tradeoffs between the unrolled and one-call Ragas generation paths?
# When would you choose each one?
#
# ##### ✅ Answer
#
# It's the same reason as why for example in previous notebooks you would use the create_agent helper function versus writing out each setup: it's a tradeoff between readability and customization. If you're okay with setting things less explicitly and going with the default path, then using the onecall is fine. However, if you have very bespoke custom needs then maybe you need to seperate out all the steps and write them yourselves.
#
# You can also make a readability argument for either. The one-call is concise, but people might not be familiar with the default paths they entail (this is less of an issue with tools like claude code but you still need to be responsible you understand the consequnces of every line committed to your codebase permanently). On the other hand, writing things out might introduce a lot of complicated hard-to-maintain logic (although ai coding tools are amazing, I've found like humans the more garbage you build on top of, the more likely they are to get confused and not complete the outlined task).

# %% [markdown]
# ## 🏗️ Activity #1: Review and Curate the Dataset
#
# Review every generated row before uploading it.
#
# For each example, check:
#
# 1. Is the question answerable from the reference contexts?
# 2. Is the reference answer fully supported by those contexts?
# 3. Is the wording natural for a plausible user?
# 4. Does the example duplicate another row?
# 5. Does it preserve the corpus's medical-safety boundaries?
#
# Requirements:
#
# - Remove or repair at least one weak example, if one exists.
# - Record why you kept, edited, or removed it.
# - Keep the synthesizer name in metadata so you can diagnose query-type failures.

# %%
# print all user input, reference_ contexts, reference, and synthesizer_name one row at a time. But prettify it so it's easier to read. Use a separator line between each row.
for index, row in testset_df.iterrows():
    print(f"Example {index + 1}:")
    print(f"- user_input: {row['user_input']}")
    print(f"- reference_contexts: {row['reference_contexts']}")
    print(f"- reference: {row['reference']}")
    print(f"- synthesizer_name: {row['synthesizer_name']}")
    print("-" * 40)
# Out:
# Example 1:
# - user_input: What does the context say about Texas A&M University?
# - reference_contexts: ['VETERINARY PRACTICE GUIDELINES\n2021 AAHA/AAFP Feline Life Stage Guidelines*\nJessica Quimby, DVM, PhD, DACVIM y, Shannon Gowland, DVM, DABVP y, Hazel C. Carney, DVM, MS, DABVP,\nTheresa DePorter, DVM, MRCVS, DACVB, DECAWBM, Paula Plummer, LVT, VTS (ECC, SAIM), Jodi Westropp,\nDVM, PhD, DACVIM\nABSTRACT\nThe guidelines, authored by a Task Force ofexperts in feline clinical medicine, are an update and extension of the AAFP–AAHA\nFeline Life Stage Guidelines published in 2010. The guidelines are published simultaneously in theJournal of Feline Medicine and\nSurgery(volume 23, issue 3, pages 211–233, DOI: 10.1177/1098612X21993657) and theJournal of the American Animal Hospital\nAssociation(volume 57, issue 2, pages 51–72, DOI: 10.5326/JAAHA-MS-7189). A noteworthy change from the earlier guidelines is\nthe division of the cat’sl i f e s p a ni n t oaﬁve-stage grouping with four distinct age-related stages (kitten, young adult, mature adult,\nand senior) as well as an end-of-life stage, instead of the previous six. This simpliﬁed grouping is consistent with how pet owners\ngenerally perceive their cat’s maturation and aging process, and provides a readily understood basis for an evolving, individualized,\nlifelong feline healthcare strategy. The guidelines include a comprehensive table on the components of a feline wellness visit that\nprovides a framework for systematically implementing an individualized life stage approach to fe line healthcare. Included are\nrecommendations for managing the most critical health-related factors in relation to a cat’s life stage. These recommendations are\nfurther explained in the followi ng categories: behavior and envir onmental needs; elimination; life stage nutrition and weight\nmanagement; oral health; parasite control; vaccination; zoonoses and human safety; and recommended diagnostics based on\nlife stage. A discussion on overcoming barriers to veterinary v i s i t sb yc a to w n e r so f f e r sp r a ctical advice on one of the most\nchallenging aspects of delivering regular feline healthcare.(JA mA n i mH o s pA s s o c2021; 57:51–72. DOI 10.5326/JAAHA-MS-7189)\nAFFILIATIONS\nThe Ohio State University, Department of V eterinary Clinical Sciences, Co-\nlumbus, Ohio, USA (J.Q.); OVC Smith Lane Animal Hospital, Ontario V et-\nerinary College, Guelph, Ontario, Canada (S.G.); WestV et Emergency and\nSpecialty Center, Garden City, Idaho, USA (H.C.C.); Oakland V eterinary\nReferral Services, Bloom ﬁeld Hills, Michigan, USA (T.D.); T exas A&M Uni-\nversity V eterinary Medical T eaching Hospital, College Station, T exas, USA\n(P .P .); and University of California, Davis, School of V eterinary Medicine,\nDavis, California, USA (J.W.).\nKEYWORDS\nFeline life stage; kitten; adult; senior; veterinary; healthcare examination;\nmedical history; behavior; risk assessment; elimination\nCorrespondence: quimby.19@osu.edu (J.Q.)\n* Boehringer Ingelheim Animal Health USA Inc., CareCredit, Dechra Vet-\nerinary Products, IDEXX Laboratories, Inc., Merck Animal Health, and Zoetis\nPetcare supported the development of the 2021 AAHA/AAFP Feline Life\nStage Guidelinesand resources through an educational grant to AAHA.\n† J. Quimby and S. Gowland were cochairs of the 2021 AAHA/AAFP\nFeline Life Stage Guidelines Task Force.\nThese guidelines were prepared by a Task Force of experts convened\nby the American Animal Hospital Association (AAHA) and the American\nAssociation of Feline Practitioners (AAFP) and were subjected to a for-\nmal peer-review process. This document is intended as a guideline only,\nnot an AAHA or AAFP standard of care. These guidelines and recom-\nmendations should not be construed as dictating an exclusive protocol,\ncourse of treatment, or procedure. Variations in practice may be war-\nranted based on the needs of the individual patient, resources, and\nlimitations unique to each individual practice setting. Evidence-based\nsupport for speciﬁc recommendations has been ci ...
# - reference: The context lists Texas A&M University Veterinary Medical Teaching Hospital in College Station, Texas, USA as one of the affiliations.
# - synthesizer_name: single_hop_specific_query_synthesizer
# ----------------------------------------
# Example 2:
# - user_input: What is spxChrome/E+ in the context of this feline life stage guideline excerpt?
# - reference_contexts: ['Introduction\nThe feline patient ’s life stage is the most fundamental presentation\nfactor the practitioner encounters in a regular examination visit.\nMost of the components of a treatment or healthcare plan are\nguided by the patient ’s life stage, progressing from kitten to young\nadult, mature adult, and senior and concluding with the end-of-life\nstage. Because a cat can transition from one life stage to another in a\nshort period of time, each examination visit should include a life\nstage assessment. The 2021 AAHA/AAFP Feline Life Stage Guidelines\nprovide a comprehensive age-associated framework for promoting\nhealth and longevity throughout a cat ’s lifetime. The guidelines were\ndeveloped by a T ask Force of experts in feline clinical medicine.\nTheir recommendations are a practical resource to guide individu-\nalized risk assessment, preventive healthcare strategies, and treat-\nment pathways that evolve as the cat matures.\nAn evidence-guided framework for managing a cat ’s healthcare\nthroughout its lifetime has never been more important in feline\npractice than it is now. Cats are the most popular pet in the United\nStates.\n1 A great anomaly in feline practice is that although most\nowners consider their cats to be family members, cats are sub-\nstantially underserved in the primary care setting compared with\ndogs.\n2 In 2006, owners took their dogs to veterinarians more than\ntwice as often as cats: 2.3 times/year for dogs versus 1.1 times/year\nfor cats.\n3 This healthcare use imbalance persists to the present day.\nCat owners often express a belief that their pets “do not need\nmedical care.” Two reasons for this misconception are that signs of\nillness and pain are often dif ﬁcult to detect in the sometimes re-\nclusive or stoic cat, and that cats are perceived to be self-suf ﬁcient.\nSpeciﬁc objectives of the guidelines are (1) to de ﬁne distinct\nfeline life stages consistent with how pet owners generally perceive\nTABLE 1\nFeline Life Stages\nª Voren1/iStock, spxChrome/E+, AaronAmat/iStock, AngiePhotos/iStock via Getty Images Plus\n52 JAAHA | 57:2 Mar/Apr 2021']
# - reference: spxChrome/E+ is listed in the image credits at the end of the excerpt: "ª Voren1/iStock, spxChrome/E+, AaronAmat/iStock, AngiePhotos/iStock via Getty Images Plus."
# - synthesizer_name: single_hop_specific_query_synthesizer
# ----------------------------------------
# Example 3:
# - user_input: How do client education and compliance improvement work together to help cat owners follow dental care recommendations?
# - reference_contexts: ['<1-hop>\n\nevents to increase knowledge and con ﬁdence when taking patient\nhistories (see “Conducting Effective Patient Histories” box) and pro-\nviding client education are just as important as further education on\nfeline-friendly handling, disease processes, and technical skills.\nIdeally, client education is a key responsibility for all staff\nmembers. Every life stage will have speci ﬁc items that should be\ndiscussed in the veterinary visit (see Table 2), and both veterinary\ntechnicians and veterinarians should be familiar with current rec-\nommendations and practice protocols in order to educate clients on\nthe most critical health-related factors relevant to each life stage.\nThe practice team can better connect with clients when they un-\nderstand that pet owners can become overwhelmed at veterinary\nvisits. Moreover, communicating that the cat owner is an integral\npart of the healthcare team can reinforce the veterinary-client-\npatient relationship, as well as improve compliance.\nSummary\nThe 2021 AAHA/AAFP Feline Life Stage Guidelinesdeﬁne four distinct age-\nrelated feline life stages: kitten (birth up to 1 year), young adult (1 –6\nyears), mature adult (7–10 years), and senior (greater than 10 years). End\nof life and its precursor events are aﬁfth life stage that is not age speciﬁc,\na n da r ed i s c u s s e di ns e p a r a t e2016 AAHA/IAAHPC End-of-Life Care\nGuidelines4 and the 2021 AAFP End of Life Online Educational Toolkit.5\nWithin these2021 AAHA/AAFP Feline Life Stage Guidelines,t h eT a s kF o r c e\noffers evidence-guided recommendations for eight clinical aspects of feline\nmedicine that should be managed in relation to a cat’s life stage: behavior\nand environmental needs; elimination; nutrition and weight management;\noral health; parasite control; vaccination; zoonoses and human safety; and\ndiagnostics. Additionally, important topics include feline-friendly handling\npractices, overcoming barriers to examination visits, environmental en-\nrichment, understanding feline behavior, practice team training, and client\neducation. Integrating clinical management with appropriate patient\nhandling, and practice team and client collaboration, all tailored to the\ncat’s life stage, forms the basis for an effe ctive, individualized healthcare\nstrategy that can be applied throughout the feline patient’s lifetime.\nThe Task Force gratefully acknowledges the contribution of\nMark Dana of Scienti ﬁc Communications Services, LLC, and\nthe Kanara Consulting Group, LLC, in the preparation of the\nguidelines manuscript.\nCONFLICT OF INTEREST\nHazel C. Carney has received speaking fees from Royal Canin. Jessica\nQuimby is a consultant/key opinion leader for Boehringer Ingelheim\nAnimal Health USA Inc., Dechra V eterinary Products, Elanco Animal\nHealth, Hill’s Pet Nutrition, Inc., IDEXX Laboratories, Inc., Kindred\nBiosciences, Inc., Nestlé Purina Petcare, and Royal Canin. Jodi Westropp\nhas received speaking fees from Bayer Animal Health, Nestlé Purina\nPetcare, Hill’s Pet Nutrition, Inc., and Royal Canin; served as a consultant/\nkey opinion leader for Nestlé Purina Petcare; and served on the academic\nboard for the International School of V eterinary Postgraduate Studies. The\nother members of the Task Force have no conﬂicts of interest to declare.\nFUNDING\nBoehringer Ingelheim Animal Health USA Inc., CareCredit, Dechra\nV eterinary Products, IDEXX Laboratories, Inc., Merck Animal Health,\nand Zoetis Petcare supported the development of the 2021 AAHA/\nAAFP Feline Life Stage Guidelines and resources through an educa-\ntional grant to AAHA.\nETHICAL APPROVAL\nThis work did not involve the use of animals and, therefore, ethical\napproval was not speci ﬁcally required for publication.\nAdditional Client Education Resources\nClient communication can be optimized by using online literature,\nhandouts, and tools. To help educate clients about the importance of an\nindividualized, lifelong ...
# - reference: Client education is described as a key responsibility for all staff members and as a way to improve compliance by helping owners understand that they are an integral part of the healthcare team. In the oral health section, improved client education can encourage cat owners to comply with veterinary recommendations regarding dental care, and using photographic or radiographic images of sequential oral examinations and scoring sheets can better communicate the degree and progression of pathology.
# - synthesizer_name: multi_hop_abstract_query_synthesizer
# ----------------------------------------
# Example 4:
# - user_input: How do the guidelines connect nail trimming and protection of household items with preventive care in young adult and senior cats?
# - reference_contexts: ['<1-hop>\n\nincluding carpeting, window and door frames, curtains, and couches.\nKeeping the nails shorter can minimize the damage to household items\nas well as to people. Moreover, meeting the cat ’s environmental needs\nmay be bene ﬁcial in reducing scratching of unwanted surfaces.\n38 Any\nintercat-related issues should be identi ﬁed and addressed as soon as\npossible, as these can lead to increased territorial scratching behaviors.51\nScratching posts and a variety of other scratching surfaces should be\nprovided for cats as soon as they enter the home. Cats may have individual\nscratching habits, but consider provision of posts near resting areas and\nhigh-trafﬁc pathways. Available scratching substrates include rope, card-\nboard, carpet, and wood. One study revealed that rope was most frequently\nused when offered, although carpet was offered more commonly.\n52 Cats\nscratched the preferred substrate more often when the post was a simple\nu p r i g h tt y p eo rac a tt r e ew i t ht w oo rm o r el e v e l sa n da tl e a s t3f th i g h .\nN a r r o w e rp o s t s( b a s ew i d t hl e s st h a no re q u a lt o3f t )w e r eu s e dm o r e\noften than wider posts (base width greater than or equal to 5 ft). Cats\nbetween the ages of 10 and 14 years preferred carpet substrate. All other\nages preferred rope.\n52 The preference of older cats for carpet may be due\nto age-related musculoskeletal changes or because these cats may not have\nhad the opportunity to use the range of substrates as kittens. “Claw\nCounseling: Helping Clients Live Alongside Cats with Claws”51 is one of\nseveral resources in the AAFP Claw Friendly Educational T oolkit.53\nYoung Adult Cats\nY oung adult cats do not require as frequent routine medical care as\nkittens, so it is integral to educate the client about why regular\nhealthcare examinations remain so important. Routine examinations\ncan help identify behavioral changes or medical concerns that may\naffect a cat ’s health long before they become signi ﬁcant, painful, or\nmore costly to treat. Clients should be educated about the subtle\nchanges in behavior and day-to-day life of the cat that may possibly\nbe signi ﬁcant. Encouraging owners to routinely record behaviors in\na journal and/or with photos and video will provide a basis for\ndocumenting any such changes. Simply asking the client, “Is your\ncat happy? ” may help them think about their cat ’s welfare.\nUrine marking is most often displayed by intact male cats,\nalthough one study reported that about 10% of sterilized cats marked\ntheir territory with urine.\n54 The onset of this behavior can coincide\nwith sexual maturity. Both males and females may urine spray.\nCats may discontinue litter box use for a variety of reasons including\nthe litter substrate offered, litter box cleaning and environmental hygiene,\nlitter box style (e.g., covered, electronic), litter box size, location preferences,\nillness, or stress in the home, including conﬂict between housemate cats.\nAlthough individual preferences can vary, of the available litter types, most\nadult cats prefer clumping litter, and most cats prefer plain unscented\nlitters.\n55 Some cats may ﬁnd scented litters signiﬁcantly aversive.56 Cats\nhave shown a tendency to prefer larger litter boxes.57,58\nIntercat Relations\nThe reduction in social play combined with the dispersal effect (when\nfree-living offspring leave the family unit at about 1 –2 years of age)\nmeans that intercat aggression may develop at this stage of life.\nConﬂict may occur when a new cat is introduced. Alternatively, a\nhousemate cat may become the target of aggression following a\nstressful event (e.g., returning home from a veterinary visit) or\nowing to redirected aggression triggered by a cat outside the home.\nControversy exists over whether cats should be kept indoors only\nor in an indoor/outdoor environment (see the “Lifestyle Choices”\nbox). These debates re ﬂect geographical and cu ...
# - reference: The guidelines say that keeping a cat’s nails shorter can minimize damage to household items and to people, and that scratching posts and other scratching surfaces should be provided as soon as cats enter the home. They also note that meeting the cat’s environmental needs may help reduce scratching of unwanted surfaces. In the preventive care context, regular healthcare examinations are emphasized for young adult cats because they can identify behavioral changes or medical concerns early, before they become significant, painful, or more costly to treat. For senior cats, new or unusual behavior, including changes in litter box use or jumping and climbing, should be evaluated for medical conditions, and veterinary visits may be made easier with pheromones or pre-visit medications to reduce stress while allowing thorough evaluations.
# - synthesizer_name: multi_hop_abstract_query_synthesizer
# ----------------------------------------
# Example 5:
# - user_input: According to the feline life stage guidelines and the preventive care recommendations, why should each examination visit include a life stage assessment in the United States, and how does this relate to individualized vaccination protocols and parasite control for cats?
# - reference_contexts: ['<1-hop>\n\ndisease, masses, or orofacial pain can be made before problems es-\ncalate and cause pain and hyporexia. 107,113,114\nThe use of photographic or radiographic images of sequential\noral examinations, as well as scoring sheets for dental pathology,\ngenerally better communicates the degree and progression of pathology.\nImproved client education can encourage cat owners to comply\nwith veterinary recommendations regarding dental care. Periodic\ncomplete dental prophylaxis, including full oral dental radiography,\neven if gross pathology is not present, can be bene ﬁcial.\n107 The use\nof feline-friendly handling techniques and anxiolytics will allow a\nmore thorough oral examination. Only after the patient has been\nanesthetized can a complete and thorough oral evaluation be suc-\ncessfully performed. The comprehensive examination includes a\ntooth-by-tooth visual assessment, probing, mobility assessment,\nradiographic examination, and oral examination charting.\n115,116\nAnesthesia-free dentistry is not appropriate because of patient stress,\ninjury, risk of aspiration, and lack of diagnostic capabilities. Fur-\nthermore, because this procedure is intended only to clean the\nvisible surface of the teeth, it provides the pet owner with a false\nsense of bene ﬁt to their pet ’s oral health.\n117–119\nParasite Control\nFor kittens and newly adopted cats with an unknown history of\nmedical care, it is prudent to administer prophylactic treatment for\nparasites with broad-spectrum products ef ﬁcacious against heart-\nworms, intestinal parasites, and ﬂeas.\n17,120,121 This approach will\neliminate existing infections, as well as decrease the risk of further\ninfestation and subsequent associated clinical problems. Canine and\nfeline housemates may be at risk of transmission of infectious\nparasites including roundworm and ﬂeas and therefore should be\ntreated in synchronicity with newly acquired kittens or cats. Pre-\nventing cats ’ access to gardens and children ’s play sand areas will,\ncombined with parasite prophylaxis, decrease environmental con-\ntamination with infectious and zoonotic agents such as hookworms\nand Toxoplasma gondii.\n33\nRoutine, regular use of broad-spectrum products is likely to be\nbeneﬁcial for the majority of pet cats, regardless of lifestyle. Certain\noutdoor lifestyles, geographic location, and whether a cat spends time\naway from the home (travel, boarding facilities, groomer, etc.) may\nincrease the existing risk of parasitic infection. Thus, recommen-\ndations for prevention and control should re ﬂect knowledge of the\nrisks and bene ﬁts for the individual cat. Fecal examinations, when\nappropriate, may diagnose speci ﬁc infections and guide therapy;\nhowever, negative testing does not rule out infection. Ectoparasite\nprevention will lower the risk of cutaneous and systemic diseases.\n120\nAs tick populations increase in number and expand geographically,\nthe prevention of tick infestations in cats is becoming increasingly\nimportant. Ticks may act as vectors of feline diseases such as\nrickettsial infection and hemotropic mycoplasmosis, and cats may act\nas transport hosts of infected ticks to humans.\n122,123 There has been an\nupward trend in heartworm incidence reported by veterinarians over\nthe past 3 years in the United States.\n124 Prevention of heartworm\ninfection, and subsequent feline HARD or heartworm disease, is\npreferable, as diagnosis is challenging at best and treatment dif ﬁcult\nbecause of the inherent risks associated with therapy.\n125\nVaccination\nPractitioners can develop individualized vaccination protocols\nconsisting of core vaccines (rabies virus, feline herpesvirus type 1\n[FHV-1], feline calicivirus [FCV], and feline panleukopenia virus\n[FPV]) and non-core vaccines based on exposure and susceptibility\nrisk as deﬁned by the patient’s life stage, lifestyle, and place of origin as\nwell as by environmental and epidemiologic factors.\nT ...
# - reference: Each examination visit should include a life stage assessment because a cat can transition from one life stage to another in a short period of time, and most components of a treatment or healthcare plan are guided by the patient’s life stage, from kitten to young adult, mature adult, senior, and end-of-life. The guidelines provide a comprehensive age-associated framework for promoting health and longevity throughout a cat’s lifetime, and they are intended to guide individualized risk assessment, preventive healthcare strategies, and treatment pathways as the cat matures. This connects to preventive care recommendations in the United States because veterinarians are advised to develop individualized vaccination protocols based on life stage, lifestyle, place of origin, and environmental and epidemiologic factors, while parasite prevention should also reflect the individual cat’s risks and benefits. For example, core vaccines should be given to every animal, non-core vaccines no more frequently than necessary based on risk exposure, and parasite prophylaxis is recommended to reduce infestation and associated clinical problems, especially for kittens and newly adopted cats or cats with increased exposure risk.
# - synthesizer_name: multi_hop_specific_query_synthesizer
# ----------------------------------------
# Example 6:
# - user_input: According to the ISFM-related feline life stage guidelines, how do feline-friendly handling and the life-stage-based healthcare approach work together to support lifelong feline care, and what additional ISFM-linked guidance is given about preventive care and diagnostics for mature adult and senior cats?
# - reference_contexts: ['<1-hop>\n\ntheir cat’s maturation and aging process, and (2) to provide a readily\nunderstood basis for an evolving, individualized, lifelong healthcare\nstrategy for each feline patient at every life stage. In this regard, the\nTask Force has identiﬁed certain common features of each feline life\nstage that provide an incentive for regular healthcare visits and\ninform a patient-speci ﬁch e a l t h c a r ea p p r o a c h .T h e s el i f es t a g e\ncharacteristics are de ﬁned in a comprehensive table listing the\nclient discussion topics and action items for each feline life stage.\nIn effect, the table de ﬁn e sw h a tn e e d st ob ed o n ea te a c hl i f es t a g e .\nThis prescriptive approach to healthcare management based on a\ncat’s life stage is explained and justi ﬁed in the well-referenced\nnarrative that makes up the rest of the guidelines. The Task\nForce considers end of life and its precursor events to be a separate\nfeline life stage. Rather than discussing end of life in these\nguidelines, practitioners can access this topic in previously pub-\nlished 2016 AAHA/IAAHPC End-of-Life Care Guidelines\n4 and the\n2021 AAFP End of Life Online Educational Toolkit .5\nA recurring emphasis throughout the guidelines is the im-\nportance of feline-friendly handling techniques in the waiting area\nand examination settings. Using feline-friendly handling is a critical\nfactor in eliminating the barriers to regular feline healthcare. This\npatient-centric approach can reduce the cat ’s stress, improve handler\nsafety, and create a more positive experience for the patient, client,\nand care provider. T ogether, these outcomes have the potential to\nincrease the frequency of feline examination visits and improve\ncompliance with preventive healthcare recommendations.\nThese guidelines complement and update earlier feline life stage\nguidelines published in 2010.\n6 An important distinction of the 2021\nguidelines is the Task Force’s decision to reduce the number of feline\nlife stages from six to four distinct age-related stages as well as an\nend-of-life stage ( ﬁve stages overall; T able 1). Although the physi-\nologic basis for six feline life stages remains valid, a ﬁve-stage\ngrouping makes clinical protocols easier to implement and sim-\npliﬁes the dialog between the practice team and cat owners. In this\nregard, the guidelines are not only a useful resource for practitioners\nbut also the basis for client education that is tailored to the feline\npatient’s life stage progression.\nThe items to perform or discuss during each life stage are\nhighlighted in Table 2. V eterinary professionals should use this table\nto identify the differences between each life stage. The text in the\nrest of the guidelines document identi ﬁes select areas in the table\nthat warrant further explanation, but is not intended as a compre-\nhensive review.\nImportance of Feline-Friendly Handling\nBoth AAHA and the AAFP understand that a major barrier to feline\nveterinary visits is the concern about the level of stress the patient will\nbe experiencing during the visit. There are many recommendations\navailable to help decrease the stress of feline patients during trans-\nportation to, and time spent in, the veterinary practice. Unless oth-\nerwise speciﬁed, the reader should assume that these stress-reduction\nrecommendations and techniques are applicable to all aspects of the\nveterinary visit at all life stages described in these guidelines.\nSafe and gentle handling will reduce the stress response of the\npatient. By applying feline-friendly handling techniques, the team\ncan proactively perform the entire examination and diagnostic\nprocedures in a way that improves patient comfort and time efﬁciency\nas well as the patient, client, and practice team experience. In efforts to\nreduce stress, keep the most invasive parts until the end, such as the\ndental examination, temperature assessment or nail trim, sample\ncollec ...
# - reference: The guidelines explain that a life-stage-based healthcare approach is used to provide an evolving, individualized, lifelong healthcare strategy for each feline patient at every life stage. The Task Force identified common features of each feline life stage and organized them into a table of client discussion topics and action items, so the team can determine what needs to be done at each stage. The 2021 guidelines also reduced the number of feline life stages from six to four age-related stages, plus an end-of-life stage, to make clinical protocols easier to implement and to simplify discussion with cat owners.
#
# Feline-friendly handling is emphasized throughout the guidelines because it helps eliminate barriers to regular feline healthcare. Safe, gentle handling reduces the cat’s stress, improves handler safety, and creates a more positive experience for the patient, client, and care provider. The guidelines say that keeping the most invasive parts of the exam until the end, such as the dental examination, temperature assessment or nail trim, sample collection, and imaging, can help reduce stress. This positive experience can carry over to future visits and improve compliance with preventive healthcare recommendations.
#
# For preventive care and diagnostics, the guidelines note that recommended diagnostics are outlined by life stage for apparently healthy cats. Regular preventive healthcare examinations and associated medical data collection can be valuable for early detection of disease or trends in clinical or laboratory parameters, such as increasing creatinine, symmetric dimethylarginine, total thyroxine, or blood pressure, and decreasing urine specific gravity. The Task Force specifically recommends that veterinarians strongly consider T4 testing in the apparently healthy mature adult cat. They also note that comorbidities are extremely common in the senior cat and can affect diagnosis, treatment, and management approaches, with additional guidance available in the AAFP Senior Care Guidelines and related ISFM consensus guidelines and toolkits.
# - synthesizer_name: multi_hop_specific_query_synthesizer
# ----------------------------------------

# %%
# Activity #1 workspace
#
# Start with every generated example. Replace this with your reviewed subset.
approved_testset_df = testset_df.copy()
review_status = "review_required"

# Examples:
# approved_testset_df = testset_df.drop(index=[2]).reset_index(drop=True)
# approved_testset_df.loc[0, "user_input"] = "Your clearer question"
# approved_testset_df.loc[0, "reference"] = "Your reviewed reference answer"
# review_status = "student_reviewed"

# example 1 edit
approved_testset_df.loc[0, "user_input"] = "What do the 2021 AAHA/AAFP Feline Life Stage Guidelines say according to researchers at Texas A&M University"

# remove example 2
approved_testset_df = testset_df.drop(index=[1]).reset_index(drop=True)

display(
    approved_testset_df[
        [
            "user_input",
            "reference_contexts",
            "reference",
            "synthesizer_name",
        ]
    ]
)
# Out:
#                                           user_input  \
# 0  What does the context say about Texas A&M Univ...
# 1  How do client education and compliance improve...
# 2  How do the guidelines connect nail trimming an...
# 3  According to the feline life stage guidelines ...
# 4  According to the ISFM-related feline life stag...
#
#                                   reference_contexts  \
# 0  [VETERINARY PRACTICE GUIDELINES\n2021 AAHA/AAF...
# 1  [<1-hop>\n\nevents to increase knowledge and c...
# 2  [<1-hop>\n\nincluding carpeting, window and do...
# 3  [<1-hop>\n\ndisease, masses, or orofacial pain...
# 4  [<1-hop>\n\ntheir cat’s maturation and aging p...
#
#                                            reference  \
# 0  The context lists Texas A&M University Veterin...
# 1  Client education is described as a key respons...
# 2  The guidelines say that keeping a cat’s nails ...
# 3  Each examination visit should include a life s...
# 4  The guidelines explain that a life-stage-based...
#
#                         synthesizer_name
# 0  single_hop_specific_query_synthesizer
# 1   multi_hop_abstract_query_synthesizer
# 2   multi_hop_abstract_query_synthesizer
# 3   multi_hop_specific_query_synthesizer
# 4   multi_hop_specific_query_synthesizer

# %% [markdown]
# ### 📝 Activity #1 Notes
#
# - Example reviewed: What is spxChrome/E+ in the context of this feline life stage guideline excerpt?
# - Decision: Rejected
# - Reason: spxChrome/E+ is not a word or concept a user would ask about; it's asking a weird translation artifact from importing our source document. Can't really salvage this question because the entire concept is nonsensical. Also the question is just weird. It would only make sense if someone was looking at THIS SPECIFIC chunk.
# - Any safety or grounding issue found: No, not really. The problem, if anything, is its too grounded in the source chunk the question was based off of.?

# %%
review_status = "student_reviewed"

# %% [markdown]
# ---
# # Breakout Room #2
# ## RAG Evaluation with LangSmith
#
# We will upload the reviewed examples, build one RAG application, and evaluate two
# retrieval settings against the same dataset and judges.
#
# Keeping the dataset and evaluators fixed makes the application change easier to
# interpret.

# %% [markdown]
# ## Task 6: Create a LangSmith Dataset
#
# The dataset stores the question as input and the reviewed synthetic answer plus
# reference contexts as outputs. Query type and provenance remain metadata.
#
# A unique suffix prevents accidental duplication when the whole notebook is rerun.
# For a long-lived team dataset, use a stable name and manage versions deliberately.

# %%
os.environ["LANGSMITH_TRACING"] = "true"
print("LangSmith tracing re-enabled for evaluation experiments")
# Out:
# LangSmith tracing re-enabled for evaluation experiments

# %%
os.environ["LANGSMITH_API_KEY"] = getpass("LangSmith API Key: ")

# %%
from langsmith import Client
client = Client()
  
# Test 1: Can you list datasets? (read)
try:
    datasets = list(client.list_datasets(limit=1))
    print(f"LIST datasets: OK ({len(datasets)} found)")
except Exception as e:
    print(f"LIST datasets: FAILED - {e}")

# Test 2: Can you list projects? (read)
try:
    projects = list(client.list_projects(limit=1))
    print(f"LIST projects: OK ({len(projects)} found)")
except Exception as e:
    print(f"LIST projects: FAILED - {e}")
# Out:
# LIST datasets: FAILED - Failed to GET /datasets in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/datasets?limit=1&offset=0', '{"detail":"Forbidden"}')
# LIST projects: FAILED - Failed to GET /sessions in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/sessions?limit=1&offset=0', '{"detail":"Forbidden"}')

# %%
def as_string_list(value) -> list[str]:
    if value is None:
        return []
    if isinstance(value, list):
        return [str(item) for item in value]
    if hasattr(value, "tolist"):
        converted = value.tolist()
        if isinstance(converted, list):
            return [str(item) for item in converted]
    return [str(value)]


if review_status != "student_reviewed":
    raise ValueError(
        "Complete Activity #1, curate approved_testset_df, and set "
        "review_status = 'student_reviewed' before uploading."
    )


langsmith_client = Client()
dataset_name = (
    "aim-session-5-cat-health-synthetic-"
    f"{uuid4().hex[:8]}"
)

langsmith_dataset = langsmith_client.create_dataset(
    dataset_name=dataset_name,
    description=(
        "Ragas-generated questions for the AI Makerspace "
        "cat health RAG lesson."
    ),
    metadata={
        "session": 5,
        "source": "ragas",
        "corpus": str(corpus_path),
    },
)

langsmith_examples = []
for _, row in approved_testset_df.iterrows():
    langsmith_examples.append(
        {
            "inputs": {
                "question": str(row["user_input"]),
            },
            "outputs": {
                "answer": str(row["reference"]),
                "reference_contexts": as_string_list(
                    row["reference_contexts"]
                ),
            },
            "metadata": {
                "synthesizer_name": str(row["synthesizer_name"]),
                "synthetic_reference": True,
                "review_status": review_status,
            },
        }
    )

langsmith_client.create_examples(
    dataset_id=langsmith_dataset.id,
    examples=langsmith_examples,
)

print(f"Created dataset: {dataset_name}")
print(f"Examples uploaded: {len(langsmith_examples)}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/src/AIEC1/05_Synthetic_Data_Generation_for_RAG_Evals/.venv/lib/python3.13/site-packages/langsmith/utils.py:181, in raise_for_status_with_text(response)
#     180 try:
# --> 181     response.raise_for_status()
#     182 except requests.HTTPError as e:
#
# File ~/src/AIEC1/05_Synthetic_Data_Generation_for_RAG_Evals/.venv/lib/python3.13/site-packages/requests/models.py:1167, in Response.raise_for_status(self)
#    1166 if http_error_msg:
# -> 1167     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.smith.langchain.com/datasets
#
# The above exception was the direct cause of the following exception:
#
# HTTPError                                 Traceback (most recent call last)
# File ~/src/AIEC1/05_Synthetic_Data_Generation_for_RAG_Evals/.venv/lib/python3.13/site-packages/langsmith/client.py:1870, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#    1868                 retry_after = retry_after * 2**idx + random.random()
#    1869                 time.sleep(retry_after)
# -> 1870             except retry_on_:
#    1871                 # Handle other exceptions more immediately
#
# File ~/src/AIEC1/05_Synthetic_Data_Generation_for_RAG_Evals/.venv/lib/python3.13/site-packages/langsmith/utils.py:183, in raise_for_status_with_text(response)
#     182 except requests.HTTPError as e:
# --> 183     raise requests.HTTPError(str(e), response.text) from e  # type: ignore[call-arg]
#     184 except httpx.HTTPStatusError as e:
#
# HTTPError: [Errno 403 Client Error: Forbidden for url: https://api.smith.langchain.com/datasets] {"detail":"Forbidden"}
#
# During handling of the above exception, another exception occurred:
#
# LangSmithError                            Traceback (most recent call last)
# Cell In[62], line 26
#      22     "aim-session-5-cat-health-synthetic-"
#      23     f"{uuid4().hex[:8]}"
#      24 )
#      25
# ---> 26 langsmith_dataset = langsmith_client.create_dataset(
#      27     dataset_name=dataset_name,
#      28     description=(
#      29         "Ragas-generated questions for the AI Makerspace "
#
# File ~/src/AIEC1/05_Synthetic_Data_Generation_for_RAG_Evals/.venv/lib/python3.13/site-packages/langsmith/client.py:5170, in Client.create_dataset(self, dataset_name, description, data_type, inputs_schema, outputs_schema, transformations, metadata)
#    5166
#    5167         if outputs_schema is not None:
#    5168             dataset["outputs_schema_definition"] = outputs_schema
#    5169
# -> 5170         response = self.request_with_retries(
#    5171             "POST",
#    5172             "/datasets",
#    5173             headers={**self._headers, "Content-Type": "application/json"},
#
# File ~/src/AIEC1/05_Synthetic_Data_Generation_for_RAG_Evals/.venv/lib/python3.13/site-packages/langsmith/client.py:1870, in Client.request_with_retries(self, method, pathname, request_kwargs, stop_after_attempt, retry_on, to_ignore, handle_response, _context, **kwargs)
#    1866                         retry_after = 30
#    1867                 # Add exponential backoff
#    1868                 retry_after = retry_after * 2**idx + random.random()
#    1869                 time.sleep(retry_after)
# -> 1870             except retry_on_:
#    1871                 # Handle other exceptions more immediately
#    1872                 if idx + 1 == stop_after_attempt:
#    1873                     raise
#
# LangSmithError: Failed to POST /datasets in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/datasets', '{"detail":"Forbidden"}')

# %% [markdown]
# #### ❓ Question #4
#
# Why is it useful to keep <code>synthesizer_name</code>,
# <code>synthetic_reference</code>, and review status as metadata instead of
# discarding them after upload?
#
# ##### ✅ Answer
#
# Because

# %% [markdown]
# ## Task 7: Build a Baseline RAG Application
#
# The baseline uses the same PDF corpus, recursive character chunks, embeddings
# and chat generation through Vercel AI Gateway, in-memory Qdrant, and a
# context-only answer prompt.
#
# The target returns both the answer and the retrieved contexts. Returning
# intermediate retrieval output makes it possible to evaluate retrieval relevance
# and answer groundedness without reconstructing hidden steps.

# %%
rag_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=75,
)
rag_documents = rag_splitter.split_documents(source_documents)

rag_embeddings = OpenAIEmbeddings(
    model=EMBEDDING_MODEL_NAME,
    api_key=gateway_api_key,
    base_url=GATEWAY_BASE_URL,
    check_embedding_ctx_length=False,
)
vector_store = QdrantVectorStore.from_documents(
    documents=rag_documents,
    embedding=rag_embeddings,
    location=":memory:",
    collection_name=f"cat_health_eval_{uuid4().hex[:8]}",
)

print(f"Source PDF pages: {len(source_documents)}")
print(f"RAG chunks: {len(rag_documents)}")
# Out:
# Source PDF pages: 20
# RAG chunks: 255

# %%
RAG_SYSTEM_PROMPT = """You are an educational cat health assistant.

Answer the question using only the retrieved context.
If the context is insufficient, say that the corpus does not provide enough
information.

Do not diagnose, prescribe treatment, or present the response as a substitute
for a veterinarian. Clearly preserve any urgent-care guidance found in the
context.

Retrieved context:
{context}
"""

rag_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", RAG_SYSTEM_PROMPT),
        ("human", "{question}"),
    ]
)
rag_llm = ChatOpenAI(
    model=RAG_MODEL_NAME,
    api_key=gateway_api_key,
    base_url=GATEWAY_BASE_URL,
)
answer_chain = rag_prompt | rag_llm | StrOutputParser()

# %%
def format_retrieved_document(document) -> str:
    page_number = document.metadata.get("page_number", "unknown")
    source = document.metadata.get("source", "course corpus")
    return (
        f"Page: {page_number}\n"
        f"Source: {source}\n"
        f"{document.page_content}"
    )


def make_rag_target(retrieval_k: int):
    retriever = vector_store.as_retriever(
        search_kwargs={"k": retrieval_k}
    )

    def target(inputs: dict) -> dict:
        question = inputs["question"]
        retrieved_documents = retriever.invoke(question)
        contexts = [
            format_retrieved_document(document)
            for document in retrieved_documents
        ]
        answer = answer_chain.invoke(
            {
                "question": question,
                "context": "\n\n".join(contexts),
            }
        )
        return {
            "answer": answer,
            "contexts": contexts,
            "retrieval_k": retrieval_k,
        }

    target.__name__ = f"cat_health_rag_k_{retrieval_k}"
    return target

# %%
baseline_retrieval_k = 3
baseline_target = make_rag_target(baseline_retrieval_k)

spot_check_question = (
    "What components should be considered during a feline wellness visit?"
)
baseline_spot_check = baseline_target(
    {"question": spot_check_question}
)

print(baseline_spot_check["answer"])
print()
print("Retrieved contexts:")
for context in baseline_spot_check["contexts"]:
    print("---")
    print(context[:700])
# Out:
# The guidelines say a feline wellness visit should consider these components:
#
# - Physical and environmental needs
# - Elimination
# - Nutrition and weight management
# - Oral health
# - Parasite control
# - Vaccination
# - Zoonoses and human safety
# - Diagnostics
#
# They also note additional important topics for the visit, including:
#
# - Feline-friendly handling practices
# - Overcoming barriers to examination visits
# - Environmental enrichment
# - Understanding feline behavior
# - Practice team training
# - Client education
#
# The corpus does not provide more detail beyond this list.
#
# Retrieved contexts:
# ---
# Page: 1
# Source: cat_health_guidelines.pdf
# lifelong feline healthcare strategy. The guidelines include a comprehensive table on the components of a feline wellness visit that
# provides a framework for systematically implementing an individualized life stage approach to fe line healthcare. Included are
# recommendations for managing the most critical health-related factors in relation to a cat’s life stage. These recommendations are
# ---
# Page: 18
# Source: cat_health_guidelines.pdf
# and environmental needs; elimination; nutrition and weight management;
# oral health; parasite control; vaccination; zoonoses and human safety; and
# diagnostics. Additionally, important topics include feline-friendly handling
# practices, overcoming barriers to examination visits, environmental en-
# richment, understanding feline behavior, practice team training, and client
# education. Integrating clinical management with appropriate patient
# ---
# Page: 7
# Source: cat_health_guidelines.pdf
# will be focused on early detection of disease. Adult and senior cats are
# often diagnosed with comorbidities. Speci ﬁc questions regarding
# changes in appetite, occurrence of polyuria and polydipsia, vomiting,
# vomiting hairballs, or diarrhea are of key importance to guide di-
# agnostic testing. Discussion should also be held with the client about
# increased nocturnal activity and vocalization as well as changes in
# the cat ’s normal habits or activity. These may indicate cognitive

# %% [markdown]
# ## Task 8: Define RAG Evaluators
#
# We will evaluate three different relationships:
#
# | Metric | Comparison |
# |---|---|
# | Answer correctness | Generated answer vs reviewed reference answer |
# | Answer groundedness | Generated answer vs contexts retrieved during that run |
# | Retrieval relevance | Retrieved contexts vs input question |
#
# These can disagree. A fluent answer can be correct but unsupported by its retrieved
# context, or well grounded in context that does not answer the question.
#
# OpenEvals provides reusable prompts, while the small wrapper functions map our
# application's dictionary keys into those prompts.

# %%
gateway_judge_llm = ChatOpenAI(
    model=JUDGE_MODEL_NAME,
    api_key=gateway_api_key,
    base_url=GATEWAY_BASE_URL,
)

correctness_judge = create_llm_as_judge(
    prompt=CORRECTNESS_PROMPT,
    feedback_key="answer_correctness",
    judge=gateway_judge_llm,
    continuous=True,
)
groundedness_judge = create_llm_as_judge(
    prompt=RAG_GROUNDEDNESS_PROMPT,
    feedback_key="answer_groundedness",
    judge=gateway_judge_llm,
    continuous=True,
)
retrieval_relevance_judge = create_llm_as_judge(
    prompt=RAG_RETRIEVAL_RELEVANCE_PROMPT,
    feedback_key="retrieval_relevance",
    judge=gateway_judge_llm,
    continuous=True,
)

# %%
def answer_correctness(
    inputs: dict,
    outputs: dict,
    reference_outputs: dict,
) -> dict:
    return correctness_judge(
        inputs=inputs["question"],
        outputs=outputs["answer"],
        reference_outputs=reference_outputs["answer"],
    )


def answer_groundedness(
    outputs: dict,
) -> dict:
    return groundedness_judge(
        context=outputs["contexts"],
        outputs=outputs["answer"],
    )


def retrieval_relevance(
    inputs: dict,
    outputs: dict,
) -> dict:
    return retrieval_relevance_judge(
        inputs=inputs["question"],
        context=outputs["contexts"],
    )


rag_evaluators = [
    answer_correctness,
    answer_groundedness,
    retrieval_relevance,
]

# %% [markdown]
# #### ❓ Question #5
#
# Give one example where answer correctness and groundedness could disagree. What
# would that disagreement tell you to inspect in the trace?
#
# ##### ✅ Answer
#
# 1. The answer could be correct but answer isn't grounded. E.g. a case where the LLM happened to provide the right answer but the chunks it based that answer off of didn't contain the right answer. In that case, you'd want to make sure a) that there are guardrails so the LLM doesn't go beyond provided context and b) you should try to tweak your retrieval process.
# 2. The answer could be wrong but the answer is grounded. E.g. the retrieved chunks were good, but the LLM somehow didn't return the right answer. In that case you'd want to look at say your prompts, or the agent design itself to make sure there aren't glaring holes.

# %% [markdown]
# ## Task 9: Run the Baseline Experiment
#
# LangSmith runs the target once for each dataset example, applies all evaluators,
# and groups the traces under one experiment.
#
# After the run, open the experiment URL and inspect individual failures. Aggregate
# scores alone do not explain whether the problem came from the generated dataset,
# retrieval, prompting, or the judge.

# %%
os.environ["LANGSMITH_TRACING"] = "true"
print("LangSmith tracing re-enabled for evaluation experiments")

# %%
baseline_results = evaluate(
    baseline_target,
    data=dataset_name,
    evaluators=rag_evaluators,
    experiment_prefix="cat-health-rag-baseline-k3",
    description=(
        "Baseline cat health RAG with 500-character chunks "
        "and retrieval k=3."
    ),
    metadata={
        "chunk_size": 500,
        "chunk_overlap": 75,
        "retrieval_k": baseline_retrieval_k,
        "embedding_model": EMBEDDING_MODEL_NAME,
        "rag_model": RAG_MODEL_NAME,
        "judge_model": JUDGE_MODEL_NAME,
        "ai_gateway_base_url": GATEWAY_BASE_URL,
    },
    max_concurrency=MAX_CONCURRENCY,
)

print(f"Baseline experiment: {baseline_results.experiment_name}")

# %% [markdown]
# ### Baseline Inspection Notes
#
# - Lowest-scoring example:
# - Metric that failed:
# - Was the synthetic reference valid?
# - Was the retrieved context relevant and sufficient?
# - Did the answer add unsupported information?

# %% [markdown]
# ## Task 10: Change One Retrieval Variable and Re-Evaluate
#
# The source notebook changed chunk size, embedding model, retriever settings, and
# prompt style at the same time. That makes any score change hard to explain.
#
# Here we change only retrieval depth:
#
# ~~~text
# baseline:  k = 3
# candidate: k = 6
# ~~~
#
# The chunks, embeddings, vector store, answer model, prompt, dataset, and evaluators
# remain fixed.

# %%
candidate_retrieval_k = 6
candidate_target = make_rag_target(candidate_retrieval_k)

candidate_spot_check = candidate_target(
    {"question": spot_check_question}
)

print(candidate_spot_check["answer"])
print()
print(
    "Retrieved context count:",
    len(candidate_spot_check["contexts"]),
)

# %%
candidate_results = evaluate(
    candidate_target,
    data=dataset_name,
    evaluators=rag_evaluators,
    experiment_prefix="cat-health-rag-candidate-k6",
    description=(
        "Candidate cat health RAG with the same index and "
        "retrieval k increased from 3 to 6."
    ),
    metadata={
        "chunk_size": 500,
        "chunk_overlap": 75,
        "retrieval_k": candidate_retrieval_k,
        "embedding_model": EMBEDDING_MODEL_NAME,
        "rag_model": RAG_MODEL_NAME,
        "judge_model": JUDGE_MODEL_NAME,
        "ai_gateway_base_url": GATEWAY_BASE_URL,
        "changed_variable": "retrieval_k",
    },
    max_concurrency=MAX_CONCURRENCY,
)

print(f"Candidate experiment: {candidate_results.experiment_name}")

# %% [markdown]
# #### ❓ Question #6
#
# Why is changing one variable at a time useful? If correctness improves while
# retrieval relevance falls, what might the larger value of <code>k</code> be doing?
#
# ##### ✅ Answer
#
# Your answer here.

# %% [markdown]
# ## 🏗️ Activity #2: Compare, Diagnose, and Iterate
#
# Compare the baseline and candidate experiments in LangSmith.
#
# Requirements:
#
# 1. Record the mean score for each evaluator in both experiments.
# 2. Inspect at least two examples whose scores changed.
# 3. Decide whether <code>k=6</code> improved the application overall.
# 4. Choose one new variable to test: chunk size, chunk overlap, embedding model,
#    prompt, or retrieval depth.
# 5. State your prediction before running the experiment.
# 6. Run a third experiment and explain the result.
#
# Keep the reviewed dataset and evaluators fixed. If you discover that an example
# itself is invalid, fix or remove the example and treat that as dataset maintenance,
# not an application improvement.

# %%
# Activity #2 workspace
#
# A retrieval-depth experiment can reuse the existing vector store:
# student_retrieval_k = 4
# student_target = make_rag_target(student_retrieval_k)
#
# If you change chunking or the embedding model, build a new vector store,
# then create a target with the same output contract:
# {
#     "answer": str,
#     "contexts": list[str],
#     "retrieval_k": int,
# }
#
# Run evaluate(...) with a descriptive experiment_prefix and metadata that
# records exactly what changed.

# %% [markdown]
# ### 📝 Activity #2 Notes
#
# - Variable changed:
# - Prediction:
# - Baseline result:
# - Candidate result:
# - Third experiment result:
# - Two traces inspected:
# - Decision:
# - Cost or latency tradeoff:

# %% [markdown]
# ## Advanced Build: Add Robustness and Adversarial Cases
#
# Synthetic data can cover failure modes as well as happy-path questions.
#
# Add at least three reviewed cases such as:
#
# - A user asks for a diagnosis or medication dose that the corpus cannot support.
# - A prompt-injection attempt asks the assistant to ignore its context-only policy.
# - An unrelated question should trigger an insufficient-context response.
# - Retrieved text contains a malicious instruction that should be treated as data,
#   not as an instruction.
#
# For each case, define the expected behavior and an evaluator that measures it.
# Track normal-task performance and attack resistance separately so a system does
# not appear safe merely because it refuses everything.

# %% [markdown]
# ## Final Takeaways
#
# - Synthetic data is a starting point for evaluation, not a replacement for human
#   review or production examples.
# - The knowledge graph and query distribution shape which capabilities the dataset
#   measures.
# - Store provenance and review metadata so failures can be traced back to the data.
# - Return retrieval output from the target when retrieval and grounding matter.
# - Evaluate retrieval, grounding, and answer quality separately.
# - Change one application variable at a time when you want an interpretable result.
